# %% [markdown]
# # Record Audio in a Notebook
#
# 1. Install dependencies
#
# 2. Enable Widgets
#
# 3. Restart Jupyter
#
# 4. Hit record and break some windows

# %%
#!pip install torchaudio ipywebrtc
#!sudo apt update
#!sudo apt install ffmpeg
#!jupyter nbextension enable --py widgetsnbextension

# %%
from ipywebrtc import AudioRecorder, CameraStream
import torchaudio
from IPython.display import Audio
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-fb9369ef2f79> in <module>
# ----> 1 from ipywebrtc import AudioRecorder, CameraStream
#       2 import torchaudio
#       3 from IPython.display import Audio
#
# ModuleNotFoundError: No module named 'ipywebrtc'

# %%
camera = CameraStream(constraints={'audio': True,'video':False})
recorder = AudioRecorder(stream=camera)
recorder
# Out:
# AudioRecorder(audio=Audio(value=b'', format='webm'), stream=CameraStream(constraints={'audio': True, 'video': …

# %%
with open('recording.webm', 'wb') as f:
    f.write(recorder.audio.value)
# !ffmpeg -i recording.webm -ac 1 -f wav file.wav -y -hide_banner -loglevel panic
sig, sr = torchaudio.load("file.wav")
print(sig.shape)
Audio(data=sig, rate=sr)
# Out:
# torch.Size([1, 123840])
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
